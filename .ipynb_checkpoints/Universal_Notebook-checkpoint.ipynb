# %%
run main.py
# Out:
# <div>
#
#
#             <div id="d13343f9-9e5e-4fec-bd25-73d3b5ad0da6" class="plotly-graph-div" style="height:1000px; width:1000px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d13343f9-9e5e-4fec-bd25-73d3b5ad0da6")) {
#                     Plotly.newPlot(
#                         'd13343f9-9e5e-4fec-bd25-73d3b5ad0da6',
# ...
